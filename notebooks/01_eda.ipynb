# %%
from pathlib import Path
import pandas as pd
from ydata_profiling import ProfileReport

# %%
ROOT = Path.cwd().parent
data_path = ROOT / "hawaii_data" / "Hawaii_2020_12.csv"

# %% [markdown]
# # Data Ingestion
# Loading the raw CSV file for initial exploratory data analysis (EDA).

# %%
# Load the data
df = pd.read_csv(data_path)

# Initialize the report
profile = ProfileReport(df, title="Profiling Report", explorative=True)

# Display it right here in VS Code
profile.to_notebook_iframe()

# %%
# 1. Save it as a separate website file
profile.to_file(ROOT / "notebooks" / "01_eda.html")
